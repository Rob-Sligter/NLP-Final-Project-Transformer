# %% [markdown]
# # Notebook for Neural Machine Translation
# Welcome to the programming portion of the assignment! Each assignment throughout the semester will have a written portion and a programming portion. We will be using [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#recent=true).

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
#%pip install torch==1.8.0
# or for GPU support:
#%pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
#%pip install transformers==4.27.0
#%pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
#%pip install nltk==3.8.1
#%pip install "numpy<2"

# Additional Libraries:
#%pip install ipywidgets
#%pip install matplotlib

# %%
#!pip install --upgrade datasets

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
#!wget -O resources.zip "https://github.com/Tsegaye-misikir/NLP-rug/raw/main/MLT/resources.zip"
#!unzip -q resources.zip

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")


# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`
    french_tokens = source_tokenizer(example['text_fr'])
    english_tokens = target_tokenizer(example['text_en'])
    return {"encoder_input_ids": french_tokens["input_ids"], "decoder_input_ids": english_tokens["input_ids"]}

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        self.hidden_size = hidden_size
        self.num_attention_heads = num_attention_heads
        self.head_dim = hidden_size // num_attention_heads  # Size per head

        # Projection matrices for Q, K, V
        self.query_proj = nn.Linear(hidden_size, hidden_size, bias=False)
        self.key_proj = nn.Linear(hidden_size, hidden_size, bias=False)
        self.value_proj = nn.Linear(hidden_size, hidden_size, bias=False)

        # Output projection (to transform attention output back)
        self.out_proj = nn.Linear(hidden_size, hidden_size, bias=False)

        # Save flags
        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention

    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.
        mask = torch.triu(torch.ones(sequence_length, sequence_length, device=device) * -1e6, diagonal=1)
        return mask.unsqueeze(0).unsqueeze(0)

    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)
        if self.is_cross_attention:
            query = self.query_proj(hidden_states)
            key = self.key_proj(encoder_outputs)
            value = self.value_proj(encoder_outputs)
        else:
            query = self.query_proj(hidden_states)
            key = self.key_proj(hidden_states)
            value = self.value_proj(hidden_states)

        batch_size, seq_length, _ = hidden_states.size()
        query = query.view(batch_size, seq_length, self.num_attention_heads, self.head_dim).transpose(1, 2)
        key = key.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)
        value = value.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)

        dot_product = torch.matmul(query, key.transpose(-2, -1)) 
        attention_scores = self.scale(dot_product, self.head_dim)

        if self.is_causal_attention:
            causal_mask = self.causal_attention_mask(seq_length, device=hidden_states.device)
            attention_scores = attention_scores + causal_mask

        if key_padding_mask is not None:
            attention_scores = attention_scores.masked_fill(key_padding_mask.unsqueeze(1).unsqueeze(2), -1e6)

        attention_weights = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_weights, value)

        attention_output = attention_output.transpose(1, 2).contiguous().view(batch_size, seq_length, self.hidden_size)
        layer_output = self.out_proj(attention_output)

        return layer_output, attention_weights
    
    def scale(self, dot_product: torch.FloatTensor, head_dim: int) -> torch.FloatTensor:
        """Scales the dot product by the square root of the head dimension.

        Args:
            dot_product: The dot-product tensor of shape (batch_size, num_heads, sequence_length, sequence_length).
            head_dim: The dimensionality of the query and key vectors per head.

        Returns:
            The dot product scaled by 1/sqrt(head_dim).
        """
        return dot_product / math.sqrt(head_dim)


    def softmax(self, matrix):
        return F.softmax(matrix, dim=1)

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.imshow(attention_matrix, cmap='hot', interpolation='nearest')
    plt.title(title)
    plt.colorbar()
    plt.show()

plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        
        self.token_embedding = nn.Embedding(vocab_size, hidden_size)
        self.positional_embedding = nn.Embedding(max_sequence_length, hidden_size)
        self.hidden_size = hidden_size
        self.max_sequence_length = max_sequence_length

    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.

        embedding_weights = self.token_embedding.weight
        logits = torch.matmul(decoder_output, embedding_weights.T)
        return logits

    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!
        #print(input_ids.size())
        sum = self.token_embedding(input_ids)
        positions = torch.arange(input_ids.size(1), device=input_ids.device).unsqueeze(0)
        positions = positions.expand(input_ids.size(0), -1)
        sum += self.positional_embedding(positions)
        return sum

    def PE(self, pos, i): #bruh why dont we use this..... I was so proud of this
        if i % 2 == 0:
            return math.sin(pos / 10000 ** (2 * i / self.hidden_size))
        else:
            return math.cos(pos / 10000 ** (2 * i / self.hidden_size))

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.


        self.vocab_size = source_vocab_size
        self.target_vocab_size = target_vocab_size
        self.hidden_size = hidden_size
        self.intermediate_size = intermediate_size
        self.num_attention_heads = num_attention_heads
        self.num_encoder_layers = num_encoder_layers
        self.num_decoder_layers = num_decoder_layers
        self.max_sequence_length = max_sequence_length
        self.hidden_dropout_prob = hidden_dropout_prob

        self.source_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)
        self.target_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)

        self.encoder_blocks = nn.ModuleList([TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob) for _ in range(num_encoder_layers)])
        self.decoder_blocks = nn.ModuleList([TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob, is_decoder=True) for _ in range(num_decoder_layers)])

    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function
        embeddings = self.source_embeddings(input_ids)

        # Apply the encoder blocks sequentially
        hidden_states = embeddings
        for block in self.encoder_blocks:
            hidden_states = block.forward(hidden_states, padding_mask)

        return hidden_states

    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function
        embeddings = self.target_embeddings.forward(input_ids)

        for block in self.decoder_blocks:
            hidden_states = block.forward(embeddings, padding_mask, encoder_outputs, encoder_padding_mask)

        return self.target_embeddings.compute_logits(hidden_states)

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (source_embeddings): TransformerEmbeddings(
#     (token_embedding): Embedding(3200, 32)
#     (positional_embedding): Embedding(32, 32)
#   )
#   (target_embeddings): TransformerEmbeddings(
#     (token_embedding): Embedding(3200, 32)
#     (positional_embedding): Embedding(32, 32)
#   )
#   (encoder_blocks): ModuleList(
#     (0): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder_blocks): ModuleList(
#     (0): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=False)
#         (key_proj): Linear(in_features=32, out_features=32, bias=False)
#         (value_proj): Linear(in_features=32, out_features=32, bias=False)
#         (out_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )
# Total number of trainable model parameters: 294784
# Use device: cuda
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=141.70 avg_ppl=516842718.18 speed=4359.87 words/sec time_elapsed=0.52 sec
# epoch 1 (19/272) | step 20 | avg_nll=112.34 avg_ppl=4341288.06 speed=6681.81 words/sec time_elapsed=0.87 sec
# epoch 1 (29/272) | step 30 | avg_nll=90.54 avg_ppl=331852.52 speed=7281.16 words/sec time_elapsed=1.18 sec
# epoch 1 (39/272) | step 40 | avg_nll=83.73 avg_ppl=81988.89 speed=7197.55 words/sec time_elapsed=1.51 sec
# epoch 1 (49/272) | step 50 | avg_nll=72.56 avg_ppl=29214.18 speed=6609.14 words/sec time_elapsed=1.86 sec
# epoch 1 (59/272) | step 60 | avg_nll=67.28 avg_ppl=13549.11 speed=7493.37 words/sec time_elapsed=2.16 sec
# epoch 1 (69/272) | step 70 | avg_nll=64.29 avg_ppl=6294.42 speed=7360.11 words/sec time_elapsed=2.48 sec
# epoch 1 (79/272) | step 80 | avg_nll=60.30 avg_ppl=4433.62 speed=6990.51 words/sec time_elapsed=2.81 sec
# epoch 1 (89/272) | step 90 | avg_nll=56.37 avg_ppl=2617.81 speed=7795.95 words/sec time_elapsed=3.10 sec
# epoch 1 (99/272) | step 100 | avg_nll=54.64 avg_ppl=1698.09 speed=7951.60 words/sec time_elapsed=3.40 sec
# Begin validation ...
# validation: step 100 | dev_ppl=808.0758056640625
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=48.67 avg_ppl=883.45 speed=3845.50 words/sec time_elapsed=3.99 sec
# epoch 1 (119/272) | step 120 | avg_nll=46.92 avg_ppl=641.07 speed=7236.75 words/sec time_elapsed=4.31 sec
# epoch 1 (129/272) | step 130 | avg_nll=46.19 avg_ppl=586.41 speed=7184.78 words/sec time_elapsed=4.64 sec
# epoch 1 (139/272) | step 140 | avg_nll=45.94 avg_ppl=506.10 speed=4914.26 words/sec time_elapsed=5.12 sec
# epoch 1 (149/272) | step 150 | avg_nll=43.50 avg_ppl=383.47 speed=6846.87 words/sec time_elapsed=5.46 sec
# epoch 1 (159/272) | step 160 | avg_nll=41.53 avg_ppl=330.44 speed=7476.00 words/sec time_elapsed=5.77 sec
# epoch 1 (169/272) | step 170 | avg_nll=41.63 avg_ppl=289.16 speed=6761.91 words/sec time_elapsed=6.11 sec
# epoch 1 (179/272) | step 180 | avg_nll=38.82 avg_ppl=228.44 speed=8011.27 words/sec time_elapsed=6.40 sec
# epoch 1 (189/272) | step 190 | avg_nll=39.70 avg_ppl=242.42 speed=7951.81 words/sec time_elapsed=6.69 sec
# epoch 1 (199/272) | step 200 | avg_nll=37.67 avg_ppl=195.13 speed=6990.86 words/sec time_elapsed=7.02 sec
# Begin validation ...
# validation: step 200 | dev_ppl=150.840576171875
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=37.72 avg_ppl=179.28 speed=3641.92 words/sec time_elapsed=7.66 sec
# epoch 1 (219/272) | step 220 | avg_nll=37.69 avg_ppl=178.33 speed=8117.96 words/sec time_elapsed=7.94 sec
# epoch 1 (229/272) | step 230 | avg_nll=36.85 avg_ppl=160.50 speed=7563.50 words/sec time_elapsed=8.25 sec
# epoch 1 (239/272) | step 240 | avg_nll=35.67 avg_ppl=129.71 speed=7192.30 words/sec time_elapsed=8.58 sec
# epoch 1 (249/272) | step 250 | avg_nll=37.19 avg_ppl=145.48 speed=8327.52 words/sec time_elapsed=8.87 sec
# epoch 1 (259/272) | step 260 | avg_nll=33.38 avg_ppl=101.32 speed=7658.58 words/sec time_elapsed=9.17 sec
# epoch 1 (269/272) | step 270 | avg_nll=33.90 avg_ppl=107.79 speed=7461.20 words/sec time_elapsed=9.48 sec
# epoch 2 (7/272) | step 280 | avg_nll=33.96 avg_ppl=103.93 speed=7908.11 words/sec time_elapsed=9.77 sec
# epoch 2 (17/272) | step 290 | avg_nll=31.27 avg_ppl=81.62 speed=5981.54 words/sec time_elapsed=10.15 sec
# epoch 2 (27/272) | step 300 | avg_nll=31.92 avg_ppl=83.35 speed=6448.12 words/sec time_elapsed=10.51 sec
# Begin validation ...
# validation: step 300 | dev_ppl=75.17598724365234
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=32.82 avg_ppl=90.51 speed=4277.05 words/sec time_elapsed=11.06 sec
# epoch 2 (47/272) | step 320 | avg_nll=31.32 avg_ppl=75.59 speed=7523.99 words/sec time_elapsed=11.37 sec
# epoch 2 (57/272) | step 330 | avg_nll=31.45 avg_ppl=75.41 speed=7183.52 words/sec time_elapsed=11.69 sec
# epoch 2 (67/272) | step 340 | avg_nll=31.43 avg_ppl=75.11 speed=7737.55 words/sec time_elapsed=11.99 sec
# epoch 2 (77/272) | step 350 | avg_nll=29.32 avg_ppl=62.60 speed=7436.06 words/sec time_elapsed=12.30 sec
# epoch 2 (87/272) | step 360 | avg_nll=31.01 avg_ppl=67.63 speed=7746.73 words/sec time_elapsed=12.60 sec
# epoch 2 (97/272) | step 370 | avg_nll=29.10 avg_ppl=56.32 speed=7805.51 words/sec time_elapsed=12.90 sec
# epoch 2 (107/272) | step 380 | avg_nll=29.37 avg_ppl=57.43 speed=7734.04 words/sec time_elapsed=13.20 sec
# epoch 2 (117/272) | step 390 | avg_nll=28.62 avg_ppl=52.41 speed=6783.05 words/sec time_elapsed=13.54 sec
# epoch 2 (127/272) | step 400 | avg_nll=27.49 avg_ppl=47.02 speed=7517.92 words/sec time_elapsed=13.84 sec
# Begin validation ...
# validation: step 400 | dev_ppl=46.724609375
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=29.19 avg_ppl=54.71 speed=4266.92 words/sec time_elapsed=14.39 sec
# epoch 2 (147/272) | step 420 | avg_nll=29.39 avg_ppl=53.99 speed=7102.40 words/sec time_elapsed=14.72 sec
# epoch 2 (157/272) | step 430 | avg_nll=28.23 avg_ppl=47.78 speed=7945.59 words/sec time_elapsed=15.02 sec
# epoch 2 (167/272) | step 440 | avg_nll=26.44 avg_ppl=43.52 speed=7678.16 words/sec time_elapsed=15.31 sec
# epoch 2 (177/272) | step 450 | avg_nll=26.88 avg_ppl=40.93 speed=6431.90 words/sec time_elapsed=15.67 sec
# epoch 2 (187/272) | step 460 | avg_nll=26.20 avg_ppl=39.99 speed=7129.89 words/sec time_elapsed=15.99 sec
# epoch 2 (197/272) | step 470 | avg_nll=27.79 avg_ppl=43.55 speed=8152.23 words/sec time_elapsed=16.28 sec
# epoch 2 (207/272) | step 480 | avg_nll=26.77 avg_ppl=40.23 speed=7834.12 words/sec time_elapsed=16.58 sec
# epoch 2 (217/272) | step 490 | avg_nll=25.80 avg_ppl=36.37 speed=7814.63 words/sec time_elapsed=16.87 sec
# epoch 2 (227/272) | step 500 | avg_nll=26.57 avg_ppl=37.74 speed=8048.14 words/sec time_elapsed=17.16 sec
# Begin validation ...
# validation: step 500 | dev_ppl=34.05833435058594
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=26.44 avg_ppl=38.08 speed=4411.74 words/sec time_elapsed=17.69 sec
# epoch 2 (247/272) | step 520 | avg_nll=25.32 avg_ppl=33.87 speed=7849.94 words/sec time_elapsed=17.98 sec
# epoch 2 (257/272) | step 530 | avg_nll=25.69 avg_ppl=34.21 speed=7396.70 words/sec time_elapsed=18.30 sec
# epoch 2 (267/272) | step 540 | avg_nll=26.02 avg_ppl=36.13 speed=6754.29 words/sec time_elapsed=18.64 sec
# epoch 3 (5/272) | step 550 | avg_nll=25.93 avg_ppl=36.83 speed=7670.00 words/sec time_elapsed=18.94 sec
# epoch 3 (15/272) | step 560 | avg_nll=25.71 avg_ppl=34.12 speed=7592.84 words/sec time_elapsed=19.25 sec
# epoch 3 (25/272) | step 570 | avg_nll=26.11 avg_ppl=34.57 speed=8165.99 words/sec time_elapsed=19.53 sec
# epoch 3 (35/272) | step 580 | avg_nll=25.57 avg_ppl=32.67 speed=8206.34 words/sec time_elapsed=19.82 sec
# epoch 3 (45/272) | step 590 | avg_nll=24.00 avg_ppl=28.75 speed=6993.90 words/sec time_elapsed=20.15 sec
# epoch 3 (55/272) | step 600 | avg_nll=24.40 avg_ppl=29.48 speed=6234.76 words/sec time_elapsed=20.52 sec
# Begin validation ...
# validation: step 600 | dev_ppl=29.44032859802246
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=24.99 avg_ppl=31.39 speed=3795.27 words/sec time_elapsed=21.13 sec
# epoch 3 (75/272) | step 620 | avg_nll=24.31 avg_ppl=29.90 speed=7924.31 words/sec time_elapsed=21.42 sec
# epoch 3 (85/272) | step 630 | avg_nll=25.51 avg_ppl=32.43 speed=8231.53 words/sec time_elapsed=21.70 sec
# epoch 3 (95/272) | step 640 | avg_nll=23.04 avg_ppl=25.58 speed=7630.87 words/sec time_elapsed=22.00 sec
# epoch 3 (105/272) | step 650 | avg_nll=24.42 avg_ppl=29.71 speed=7678.80 words/sec time_elapsed=22.30 sec
# epoch 3 (115/272) | step 660 | avg_nll=26.62 avg_ppl=35.30 speed=8385.92 words/sec time_elapsed=22.59 sec
# epoch 3 (125/272) | step 670 | avg_nll=24.63 avg_ppl=30.43 speed=7729.51 words/sec time_elapsed=22.89 sec
# epoch 3 (135/272) | step 680 | avg_nll=23.68 avg_ppl=27.09 speed=7839.32 words/sec time_elapsed=23.18 sec
# epoch 3 (145/272) | step 690 | avg_nll=24.71 avg_ppl=30.03 speed=7932.01 words/sec time_elapsed=23.47 sec
# epoch 3 (155/272) | step 700 | avg_nll=23.67 avg_ppl=26.56 speed=7478.01 words/sec time_elapsed=23.78 sec
# Begin validation ...
# validation: step 700 | dev_ppl=25.975542068481445
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=24.19 avg_ppl=27.30 speed=4195.34 words/sec time_elapsed=24.34 sec
# epoch 3 (175/272) | step 720 | avg_nll=23.54 avg_ppl=26.79 speed=6738.25 words/sec time_elapsed=24.68 sec
# epoch 3 (185/272) | step 730 | avg_nll=22.90 avg_ppl=24.14 speed=7229.97 words/sec time_elapsed=25.00 sec
# epoch 3 (195/272) | step 740 | avg_nll=23.79 avg_ppl=26.48 speed=8154.42 words/sec time_elapsed=25.29 sec
# epoch 3 (205/272) | step 750 | avg_nll=24.47 avg_ppl=28.89 speed=8139.89 words/sec time_elapsed=25.57 sec
# epoch 3 (215/272) | step 760 | avg_nll=23.62 avg_ppl=25.66 speed=7611.09 words/sec time_elapsed=25.88 sec
# epoch 3 (225/272) | step 770 | avg_nll=22.41 avg_ppl=23.75 speed=5617.86 words/sec time_elapsed=26.28 sec
# epoch 3 (235/272) | step 780 | avg_nll=23.29 avg_ppl=24.89 speed=6500.52 words/sec time_elapsed=26.64 sec
# epoch 3 (245/272) | step 790 | avg_nll=23.49 avg_ppl=25.05 speed=8189.46 words/sec time_elapsed=26.92 sec
# epoch 3 (255/272) | step 800 | avg_nll=23.56 avg_ppl=24.59 speed=7525.93 words/sec time_elapsed=27.24 sec
# Begin validation ...
# validation: step 800 | dev_ppl=23.86365509033203
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=23.46 avg_ppl=25.68 speed=4139.19 words/sec time_elapsed=27.80 sec
# epoch 4 (3/272) | step 820 | avg_nll=23.30 avg_ppl=26.03 speed=6426.97 words/sec time_elapsed=28.15 sec
# epoch 4 (13/272) | step 830 | avg_nll=23.30 avg_ppl=24.29 speed=7921.99 words/sec time_elapsed=28.45 sec
# epoch 4 (23/272) | step 840 | avg_nll=22.35 avg_ppl=21.45 speed=7725.11 words/sec time_elapsed=28.75 sec
# epoch 4 (33/272) | step 850 | avg_nll=23.22 avg_ppl=24.43 speed=5238.77 words/sec time_elapsed=29.19 sec
# epoch 4 (43/272) | step 860 | avg_nll=23.08 avg_ppl=24.58 speed=6480.64 words/sec time_elapsed=29.55 sec
# epoch 4 (53/272) | step 870 | avg_nll=21.98 avg_ppl=21.83 speed=6689.20 words/sec time_elapsed=29.89 sec
# epoch 4 (63/272) | step 880 | avg_nll=23.14 avg_ppl=23.64 speed=6726.98 words/sec time_elapsed=30.24 sec
# epoch 4 (73/272) | step 890 | avg_nll=22.85 avg_ppl=23.43 speed=7386.54 words/sec time_elapsed=30.55 sec
# epoch 4 (83/272) | step 900 | avg_nll=24.05 avg_ppl=25.29 speed=7683.87 words/sec time_elapsed=30.86 sec
# Begin validation ...
# validation: step 900 | dev_ppl=21.65513801574707
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=21.77 avg_ppl=22.08 speed=3473.76 words/sec time_elapsed=31.51 sec
# epoch 4 (103/272) | step 920 | avg_nll=22.57 avg_ppl=22.39 speed=6207.70 words/sec time_elapsed=31.88 sec
# epoch 4 (113/272) | step 930 | avg_nll=22.29 avg_ppl=22.10 speed=7408.47 words/sec time_elapsed=32.20 sec
# epoch 4 (123/272) | step 940 | avg_nll=22.21 avg_ppl=22.02 speed=7634.52 words/sec time_elapsed=32.50 sec
# epoch 4 (133/272) | step 950 | avg_nll=21.95 avg_ppl=21.91 speed=7462.31 words/sec time_elapsed=32.80 sec
# epoch 4 (143/272) | step 960 | avg_nll=22.68 avg_ppl=23.64 speed=6996.88 words/sec time_elapsed=33.13 sec
# epoch 4 (153/272) | step 970 | avg_nll=22.07 avg_ppl=21.07 speed=7775.25 words/sec time_elapsed=33.43 sec
# epoch 4 (163/272) | step 980 | avg_nll=22.18 avg_ppl=20.49 speed=7679.72 words/sec time_elapsed=33.74 sec
# epoch 4 (173/272) | step 990 | avg_nll=21.87 avg_ppl=20.78 speed=7572.82 words/sec time_elapsed=34.04 sec
# epoch 4 (183/272) | step 1000 | avg_nll=22.97 avg_ppl=23.24 speed=7868.66 words/sec time_elapsed=34.34 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=20.20676040649414
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=22.97 avg_ppl=22.99 speed=4287.61 words/sec time_elapsed=34.89 sec
# epoch 4 (203/272) | step 1020 | avg_nll=22.34 avg_ppl=21.65 speed=6961.04 words/sec time_elapsed=35.22 sec
# epoch 4 (213/272) | step 1030 | avg_nll=22.47 avg_ppl=22.02 speed=7548.70 words/sec time_elapsed=35.53 sec
# epoch 4 (223/272) | step 1040 | avg_nll=21.90 avg_ppl=20.45 speed=5863.60 words/sec time_elapsed=35.93 sec
# epoch 4 (233/272) | step 1050 | avg_nll=22.39 avg_ppl=21.41 speed=7502.48 words/sec time_elapsed=36.24 sec
# epoch 4 (243/272) | step 1060 | avg_nll=20.99 avg_ppl=18.92 speed=5440.49 words/sec time_elapsed=36.66 sec
# epoch 4 (253/272) | step 1070 | avg_nll=21.92 avg_ppl=20.18 speed=5901.35 words/sec time_elapsed=37.05 sec
# epoch 4 (263/272) | step 1080 | avg_nll=21.71 avg_ppl=19.91 speed=7175.94 words/sec time_elapsed=37.38 sec
# epoch 5 (1/272) | step 1090 | avg_nll=20.51 avg_ppl=18.36 speed=6643.74 words/sec time_elapsed=37.72 sec
# epoch 5 (11/272) | step 1100 | avg_nll=21.85 avg_ppl=19.76 speed=7280.39 words/sec time_elapsed=38.04 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=19.153013229370117
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=21.06 avg_ppl=18.05 speed=4105.62 words/sec time_elapsed=38.61 sec
# epoch 5 (31/272) | step 1120 | avg_nll=22.27 avg_ppl=20.90 speed=6096.48 words/sec time_elapsed=38.99 sec
# epoch 5 (41/272) | step 1130 | avg_nll=20.81 avg_ppl=18.15 speed=6638.76 words/sec time_elapsed=39.34 sec
# epoch 5 (51/272) | step 1140 | avg_nll=21.81 avg_ppl=19.80 speed=7081.86 words/sec time_elapsed=39.67 sec
# epoch 5 (61/272) | step 1150 | avg_nll=21.16 avg_ppl=18.77 speed=6956.27 words/sec time_elapsed=40.00 sec
# epoch 5 (71/272) | step 1160 | avg_nll=21.93 avg_ppl=20.07 speed=6965.02 words/sec time_elapsed=40.34 sec
# epoch 5 (81/272) | step 1170 | avg_nll=21.55 avg_ppl=19.33 speed=6512.90 words/sec time_elapsed=40.69 sec
# epoch 5 (91/272) | step 1180 | avg_nll=19.64 avg_ppl=16.38 speed=6350.20 words/sec time_elapsed=41.05 sec
# epoch 5 (101/272) | step 1190 | avg_nll=21.19 avg_ppl=19.38 speed=7181.05 words/sec time_elapsed=41.37 sec
# epoch 5 (111/272) | step 1200 | avg_nll=20.92 avg_ppl=17.96 speed=4206.89 words/sec time_elapsed=41.92 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=18.35434913635254
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=20.48 avg_ppl=18.03 speed=2566.05 words/sec time_elapsed=42.80 sec
# epoch 5 (131/272) | step 1220 | avg_nll=20.90 avg_ppl=17.48 speed=5925.02 words/sec time_elapsed=43.20 sec
# epoch 5 (141/272) | step 1230 | avg_nll=20.20 avg_ppl=16.81 speed=4843.58 words/sec time_elapsed=43.67 sec
# epoch 5 (151/272) | step 1240 | avg_nll=20.51 avg_ppl=17.52 speed=5937.21 words/sec time_elapsed=44.06 sec
# epoch 5 (161/272) | step 1250 | avg_nll=22.35 avg_ppl=20.77 speed=6568.90 words/sec time_elapsed=44.42 sec
# epoch 5 (171/272) | step 1260 | avg_nll=21.73 avg_ppl=19.26 speed=6640.56 words/sec time_elapsed=44.77 sec
# epoch 5 (181/272) | step 1270 | avg_nll=20.32 avg_ppl=16.46 speed=6007.76 words/sec time_elapsed=45.16 sec
# epoch 5 (191/272) | step 1280 | avg_nll=20.56 avg_ppl=17.72 speed=6357.67 words/sec time_elapsed=45.52 sec
# epoch 5 (201/272) | step 1290 | avg_nll=21.27 avg_ppl=19.05 speed=5758.70 words/sec time_elapsed=45.92 sec
# epoch 5 (211/272) | step 1300 | avg_nll=21.02 avg_ppl=18.24 speed=6209.07 words/sec time_elapsed=46.29 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=17.97056770324707
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=20.70 avg_ppl=17.60 speed=3477.58 words/sec time_elapsed=46.96 sec
# epoch 5 (231/272) | step 1320 | avg_nll=21.53 avg_ppl=18.98 speed=6846.68 words/sec time_elapsed=47.30 sec
# epoch 5 (241/272) | step 1330 | avg_nll=20.93 avg_ppl=17.48 speed=6614.06 words/sec time_elapsed=47.65 sec
# epoch 5 (251/272) | step 1340 | avg_nll=21.54 avg_ppl=18.68 speed=6534.64 words/sec time_elapsed=48.01 sec
# epoch 5 (261/272) | step 1350 | avg_nll=20.56 avg_ppl=17.12 speed=5610.26 words/sec time_elapsed=48.43 sec
# epoch 5 (271/272) | step 1360 | avg_nll=20.47 avg_ppl=17.45 speed=6798.24 words/sec time_elapsed=48.76 sec
# epoch 6 (9/272) | step 1370 | avg_nll=20.16 avg_ppl=16.51 speed=7145.93 words/sec time_elapsed=49.09 sec
# epoch 6 (19/272) | step 1380 | avg_nll=21.06 avg_ppl=17.48 speed=6159.98 words/sec time_elapsed=49.47 sec
# epoch 6 (29/272) | step 1390 | avg_nll=19.88 avg_ppl=15.87 speed=6396.60 words/sec time_elapsed=49.83 sec
# epoch 6 (39/272) | step 1400 | avg_nll=19.73 avg_ppl=15.58 speed=6247.18 words/sec time_elapsed=50.20 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=16.828763961791992
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=20.56 avg_ppl=16.87 speed=3433.64 words/sec time_elapsed=50.88 sec
# epoch 6 (59/272) | step 1420 | avg_nll=20.39 avg_ppl=17.00 speed=6580.00 words/sec time_elapsed=51.23 sec
# epoch 6 (69/272) | step 1430 | avg_nll=20.27 avg_ppl=16.19 speed=5701.95 words/sec time_elapsed=51.63 sec
# epoch 6 (79/272) | step 1440 | avg_nll=19.29 avg_ppl=15.12 speed=6535.33 words/sec time_elapsed=51.98 sec
# epoch 6 (89/272) | step 1450 | avg_nll=20.61 avg_ppl=16.99 speed=6708.98 words/sec time_elapsed=52.33 sec
# epoch 6 (99/272) | step 1460 | avg_nll=20.72 avg_ppl=17.57 speed=6611.14 words/sec time_elapsed=52.68 sec
# epoch 6 (109/272) | step 1470 | avg_nll=20.26 avg_ppl=15.66 speed=7459.72 words/sec time_elapsed=53.00 sec
# epoch 6 (119/272) | step 1480 | avg_nll=20.13 avg_ppl=16.07 speed=6884.28 words/sec time_elapsed=53.33 sec
# epoch 6 (129/272) | step 1490 | avg_nll=19.58 avg_ppl=15.25 speed=7165.14 words/sec time_elapsed=53.66 sec
# epoch 6 (139/272) | step 1500 | avg_nll=19.05 avg_ppl=14.48 speed=6846.63 words/sec time_elapsed=53.99 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=16.42023468017578
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=20.33 avg_ppl=16.28 speed=3893.15 words/sec time_elapsed=54.59 sec
# epoch 6 (159/272) | step 1520 | avg_nll=20.06 avg_ppl=16.36 speed=6856.74 words/sec time_elapsed=54.92 sec
# epoch 6 (169/272) | step 1530 | avg_nll=19.32 avg_ppl=14.71 speed=6460.70 words/sec time_elapsed=55.28 sec
# epoch 6 (179/272) | step 1540 | avg_nll=20.76 avg_ppl=17.09 speed=7015.67 words/sec time_elapsed=55.62 sec
# epoch 6 (189/272) | step 1550 | avg_nll=20.35 avg_ppl=16.49 speed=6976.02 words/sec time_elapsed=55.95 sec
# epoch 6 (199/272) | step 1560 | avg_nll=20.02 avg_ppl=16.58 speed=6759.16 words/sec time_elapsed=56.29 sec
# epoch 6 (209/272) | step 1570 | avg_nll=20.78 avg_ppl=17.11 speed=6707.74 words/sec time_elapsed=56.63 sec
# epoch 6 (219/272) | step 1580 | avg_nll=19.43 avg_ppl=14.80 speed=6845.70 words/sec time_elapsed=56.97 sec
# epoch 6 (229/272) | step 1590 | avg_nll=19.49 avg_ppl=14.88 speed=7427.62 words/sec time_elapsed=57.28 sec
# epoch 6 (239/272) | step 1600 | avg_nll=21.33 avg_ppl=17.51 speed=7116.41 words/sec time_elapsed=57.62 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=15.819563865661621
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=20.71 avg_ppl=17.12 speed=3738.76 words/sec time_elapsed=58.24 sec
# epoch 6 (259/272) | step 1620 | avg_nll=19.86 avg_ppl=14.87 speed=7912.29 words/sec time_elapsed=58.54 sec
# epoch 6 (269/272) | step 1630 | avg_nll=19.14 avg_ppl=14.83 speed=7329.08 words/sec time_elapsed=58.85 sec
# epoch 7 (7/272) | step 1640 | avg_nll=18.77 avg_ppl=13.72 speed=7213.79 words/sec time_elapsed=59.17 sec
# epoch 7 (17/272) | step 1650 | avg_nll=19.68 avg_ppl=15.19 speed=7874.41 words/sec time_elapsed=59.46 sec
# epoch 7 (27/272) | step 1660 | avg_nll=19.16 avg_ppl=14.19 speed=7678.25 words/sec time_elapsed=59.76 sec
# epoch 7 (37/272) | step 1670 | avg_nll=19.72 avg_ppl=15.09 speed=6940.87 words/sec time_elapsed=60.10 sec
# epoch 7 (47/272) | step 1680 | avg_nll=20.01 avg_ppl=15.34 speed=7922.23 words/sec time_elapsed=60.40 sec
# epoch 7 (57/272) | step 1690 | avg_nll=18.85 avg_ppl=14.04 speed=6910.15 words/sec time_elapsed=60.73 sec
# epoch 7 (67/272) | step 1700 | avg_nll=19.57 avg_ppl=14.01 speed=7389.48 words/sec time_elapsed=61.05 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=15.37275218963623
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=19.02 avg_ppl=13.82 speed=3933.78 words/sec time_elapsed=61.64 sec
# epoch 7 (87/272) | step 1720 | avg_nll=19.68 avg_ppl=15.11 speed=7707.66 words/sec time_elapsed=61.94 sec
# epoch 7 (97/272) | step 1730 | avg_nll=19.39 avg_ppl=14.24 speed=7918.65 words/sec time_elapsed=62.23 sec
# epoch 7 (107/272) | step 1740 | avg_nll=18.53 avg_ppl=12.83 speed=7848.74 words/sec time_elapsed=62.53 sec
# epoch 7 (117/272) | step 1750 | avg_nll=19.04 avg_ppl=14.30 speed=7279.42 words/sec time_elapsed=62.85 sec
# epoch 7 (127/272) | step 1760 | avg_nll=20.07 avg_ppl=15.47 speed=7474.57 words/sec time_elapsed=63.16 sec
# epoch 7 (137/272) | step 1770 | avg_nll=19.43 avg_ppl=14.54 speed=7543.71 words/sec time_elapsed=63.47 sec
# epoch 7 (147/272) | step 1780 | avg_nll=18.19 avg_ppl=12.58 speed=7537.41 words/sec time_elapsed=63.77 sec
# epoch 7 (157/272) | step 1790 | avg_nll=19.45 avg_ppl=14.64 speed=7828.48 words/sec time_elapsed=64.07 sec
# epoch 7 (167/272) | step 1800 | avg_nll=19.85 avg_ppl=14.99 speed=8202.80 words/sec time_elapsed=64.36 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=14.857247352600098
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=19.72 avg_ppl=14.53 speed=4168.34 words/sec time_elapsed=64.92 sec
# epoch 7 (187/272) | step 1820 | avg_nll=18.96 avg_ppl=14.66 speed=6731.56 words/sec time_elapsed=65.26 sec
# epoch 7 (197/272) | step 1830 | avg_nll=19.52 avg_ppl=14.69 speed=7854.77 words/sec time_elapsed=65.56 sec
# epoch 7 (207/272) | step 1840 | avg_nll=19.16 avg_ppl=14.60 speed=6995.80 words/sec time_elapsed=65.88 sec
# epoch 7 (217/272) | step 1850 | avg_nll=19.63 avg_ppl=14.56 speed=7066.20 words/sec time_elapsed=66.22 sec
# epoch 7 (227/272) | step 1860 | avg_nll=19.36 avg_ppl=14.88 speed=7275.18 words/sec time_elapsed=66.53 sec
# epoch 7 (237/272) | step 1870 | avg_nll=19.13 avg_ppl=13.87 speed=7785.98 words/sec time_elapsed=66.83 sec
# epoch 7 (247/272) | step 1880 | avg_nll=18.61 avg_ppl=13.85 speed=6764.64 words/sec time_elapsed=67.17 sec
# epoch 7 (257/272) | step 1890 | avg_nll=19.72 avg_ppl=14.92 speed=7329.47 words/sec time_elapsed=67.49 sec
# epoch 7 (267/272) | step 1900 | avg_nll=19.03 avg_ppl=13.67 speed=7558.40 words/sec time_elapsed=67.79 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=14.745436668395996
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=17.86 avg_ppl=12.54 speed=3869.87 words/sec time_elapsed=68.38 sec
# epoch 8 (15/272) | step 1920 | avg_nll=18.34 avg_ppl=12.59 speed=7682.35 words/sec time_elapsed=68.68 sec
# epoch 8 (25/272) | step 1930 | avg_nll=18.06 avg_ppl=12.50 speed=7874.05 words/sec time_elapsed=68.97 sec
# epoch 8 (35/272) | step 1940 | avg_nll=19.72 avg_ppl=14.62 speed=8110.35 words/sec time_elapsed=69.26 sec
# epoch 8 (45/272) | step 1950 | avg_nll=17.74 avg_ppl=12.15 speed=7250.96 words/sec time_elapsed=69.57 sec
# epoch 8 (55/272) | step 1960 | avg_nll=19.04 avg_ppl=13.84 speed=7529.34 words/sec time_elapsed=69.88 sec
# epoch 8 (65/272) | step 1970 | avg_nll=18.30 avg_ppl=12.51 speed=7611.37 words/sec time_elapsed=70.19 sec
# epoch 8 (75/272) | step 1980 | avg_nll=18.34 avg_ppl=13.03 speed=7046.54 words/sec time_elapsed=70.51 sec
# epoch 8 (85/272) | step 1990 | avg_nll=17.55 avg_ppl=11.81 speed=7406.05 words/sec time_elapsed=70.82 sec
# epoch 8 (95/272) | step 2000 | avg_nll=18.64 avg_ppl=12.73 speed=7688.41 words/sec time_elapsed=71.12 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=14.212799072265625
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=18.47 avg_ppl=13.29 speed=3600.24 words/sec time_elapsed=71.76 sec
# epoch 8 (115/272) | step 2020 | avg_nll=18.81 avg_ppl=13.66 speed=6753.68 words/sec time_elapsed=72.10 sec
# epoch 8 (125/272) | step 2030 | avg_nll=18.78 avg_ppl=13.19 speed=7689.84 words/sec time_elapsed=72.40 sec
# epoch 8 (135/272) | step 2040 | avg_nll=18.84 avg_ppl=13.96 speed=6768.41 words/sec time_elapsed=72.74 sec
# epoch 8 (145/272) | step 2050 | avg_nll=18.86 avg_ppl=13.35 speed=7841.66 words/sec time_elapsed=73.04 sec
# epoch 8 (155/272) | step 2060 | avg_nll=18.37 avg_ppl=12.24 speed=7849.63 words/sec time_elapsed=73.34 sec
# epoch 8 (165/272) | step 2070 | avg_nll=19.16 avg_ppl=13.72 speed=7247.76 words/sec time_elapsed=73.66 sec
# epoch 8 (175/272) | step 2080 | avg_nll=19.65 avg_ppl=14.52 speed=7571.60 words/sec time_elapsed=73.97 sec
# epoch 8 (185/272) | step 2090 | avg_nll=19.50 avg_ppl=14.26 speed=7202.45 words/sec time_elapsed=74.30 sec
# epoch 8 (195/272) | step 2100 | avg_nll=18.58 avg_ppl=12.60 speed=7240.73 words/sec time_elapsed=74.62 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=13.984155654907227
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=17.97 avg_ppl=12.02 speed=4173.30 words/sec time_elapsed=75.18 sec
# epoch 8 (215/272) | step 2120 | avg_nll=18.18 avg_ppl=12.51 speed=7733.99 words/sec time_elapsed=75.48 sec
# epoch 8 (225/272) | step 2130 | avg_nll=18.92 avg_ppl=13.14 speed=6970.81 words/sec time_elapsed=75.81 sec
# epoch 8 (235/272) | step 2140 | avg_nll=18.51 avg_ppl=13.05 speed=6871.41 words/sec time_elapsed=76.15 sec
# epoch 8 (245/272) | step 2150 | avg_nll=19.06 avg_ppl=13.28 speed=7567.39 words/sec time_elapsed=76.46 sec
# epoch 8 (255/272) | step 2160 | avg_nll=17.85 avg_ppl=11.99 speed=6869.86 words/sec time_elapsed=76.79 sec
# epoch 8 (265/272) | step 2170 | avg_nll=17.86 avg_ppl=11.79 speed=7771.79 words/sec time_elapsed=77.09 sec
# epoch 9 (3/272) | step 2180 | avg_nll=18.02 avg_ppl=12.45 speed=6826.86 words/sec time_elapsed=77.43 sec
# epoch 9 (13/272) | step 2190 | avg_nll=17.24 avg_ppl=11.23 speed=6574.12 words/sec time_elapsed=77.78 sec
# epoch 9 (23/272) | step 2200 | avg_nll=18.78 avg_ppl=12.94 speed=7387.37 words/sec time_elapsed=78.09 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=13.33536434173584
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=17.85 avg_ppl=11.92 speed=3964.17 words/sec time_elapsed=78.68 sec
# epoch 9 (43/272) | step 2220 | avg_nll=17.46 avg_ppl=11.13 speed=7091.78 words/sec time_elapsed=79.00 sec
# epoch 9 (53/272) | step 2230 | avg_nll=17.51 avg_ppl=11.50 speed=7080.27 words/sec time_elapsed=79.33 sec
# epoch 9 (63/272) | step 2240 | avg_nll=17.74 avg_ppl=11.95 speed=7618.88 words/sec time_elapsed=79.63 sec
# epoch 9 (73/272) | step 2250 | avg_nll=17.21 avg_ppl=11.21 speed=6969.35 words/sec time_elapsed=79.95 sec
# epoch 9 (83/272) | step 2260 | avg_nll=17.63 avg_ppl=11.31 speed=7407.69 words/sec time_elapsed=80.27 sec
# epoch 9 (93/272) | step 2270 | avg_nll=18.20 avg_ppl=12.25 speed=5929.75 words/sec time_elapsed=80.66 sec
# epoch 9 (103/272) | step 2280 | avg_nll=18.19 avg_ppl=11.76 speed=6745.64 words/sec time_elapsed=81.01 sec
# epoch 9 (113/272) | step 2290 | avg_nll=17.44 avg_ppl=11.51 speed=6681.27 words/sec time_elapsed=81.35 sec
# epoch 9 (123/272) | step 2300 | avg_nll=18.09 avg_ppl=11.75 speed=7433.57 words/sec time_elapsed=81.67 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=13.185038566589355
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=17.94 avg_ppl=11.84 speed=3844.65 words/sec time_elapsed=82.27 sec
# epoch 9 (143/272) | step 2320 | avg_nll=17.75 avg_ppl=11.61 speed=7352.41 words/sec time_elapsed=82.59 sec
# epoch 9 (153/272) | step 2330 | avg_nll=18.69 avg_ppl=13.08 speed=6611.26 words/sec time_elapsed=82.94 sec
# epoch 9 (163/272) | step 2340 | avg_nll=17.32 avg_ppl=11.55 speed=6947.86 words/sec time_elapsed=83.27 sec
# epoch 9 (173/272) | step 2350 | avg_nll=18.18 avg_ppl=11.92 speed=6507.89 words/sec time_elapsed=83.63 sec
# epoch 9 (183/272) | step 2360 | avg_nll=19.08 avg_ppl=13.20 speed=7420.06 words/sec time_elapsed=83.95 sec
# epoch 9 (193/272) | step 2370 | avg_nll=17.70 avg_ppl=11.54 speed=6872.40 words/sec time_elapsed=84.28 sec
# epoch 9 (203/272) | step 2380 | avg_nll=16.74 avg_ppl=10.54 speed=6423.73 words/sec time_elapsed=84.64 sec
# epoch 9 (213/272) | step 2390 | avg_nll=18.66 avg_ppl=12.62 speed=6940.41 words/sec time_elapsed=84.98 sec
# epoch 9 (223/272) | step 2400 | avg_nll=17.46 avg_ppl=10.98 speed=7543.72 words/sec time_elapsed=85.29 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=12.628554344177246
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=17.93 avg_ppl=12.13 speed=3923.01 words/sec time_elapsed=85.87 sec
# epoch 9 (243/272) | step 2420 | avg_nll=18.82 avg_ppl=12.94 speed=7875.37 words/sec time_elapsed=86.17 sec
# epoch 9 (253/272) | step 2430 | avg_nll=17.56 avg_ppl=11.43 speed=6218.36 words/sec time_elapsed=86.54 sec
# epoch 9 (263/272) | step 2440 | avg_nll=18.21 avg_ppl=12.22 speed=6867.27 words/sec time_elapsed=86.88 sec
# epoch 10 (1/272) | step 2450 | avg_nll=17.73 avg_ppl=11.91 speed=5486.26 words/sec time_elapsed=87.30 sec
# epoch 10 (11/272) | step 2460 | avg_nll=17.89 avg_ppl=11.47 speed=6815.10 words/sec time_elapsed=87.64 sec
# epoch 10 (21/272) | step 2470 | avg_nll=16.59 avg_ppl=10.03 speed=6411.38 words/sec time_elapsed=88.00 sec
# epoch 10 (31/272) | step 2480 | avg_nll=16.92 avg_ppl=10.37 speed=6355.56 words/sec time_elapsed=88.37 sec
# epoch 10 (41/272) | step 2490 | avg_nll=16.96 avg_ppl=10.59 speed=6249.87 words/sec time_elapsed=88.74 sec
# epoch 10 (51/272) | step 2500 | avg_nll=16.92 avg_ppl=10.16 speed=4967.26 words/sec time_elapsed=89.21 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=12.575703620910645
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=17.13 avg_ppl=10.75 speed=3516.76 words/sec time_elapsed=89.86 sec
# epoch 10 (71/272) | step 2520 | avg_nll=16.74 avg_ppl=10.10 speed=7424.43 words/sec time_elapsed=90.18 sec
# epoch 10 (81/272) | step 2530 | avg_nll=18.56 avg_ppl=12.49 speed=6442.60 words/sec time_elapsed=90.54 sec
# epoch 10 (91/272) | step 2540 | avg_nll=16.44 avg_ppl=9.43 speed=7127.55 words/sec time_elapsed=90.87 sec
# epoch 10 (101/272) | step 2550 | avg_nll=17.07 avg_ppl=10.53 speed=7227.51 words/sec time_elapsed=91.19 sec
# epoch 10 (111/272) | step 2560 | avg_nll=17.61 avg_ppl=11.33 speed=6969.94 words/sec time_elapsed=91.53 sec
# epoch 10 (121/272) | step 2570 | avg_nll=17.23 avg_ppl=10.74 speed=6402.22 words/sec time_elapsed=91.89 sec
# epoch 10 (131/272) | step 2580 | avg_nll=17.43 avg_ppl=11.02 speed=7720.92 words/sec time_elapsed=92.19 sec
# epoch 10 (141/272) | step 2590 | avg_nll=17.43 avg_ppl=11.24 speed=7297.35 words/sec time_elapsed=92.51 sec
# epoch 10 (151/272) | step 2600 | avg_nll=17.37 avg_ppl=11.15 speed=6529.77 words/sec time_elapsed=92.86 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=12.419109344482422
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=17.49 avg_ppl=11.29 speed=3260.53 words/sec time_elapsed=93.57 sec
# epoch 10 (171/272) | step 2620 | avg_nll=18.23 avg_ppl=12.05 speed=5915.16 words/sec time_elapsed=93.97 sec
# epoch 10 (181/272) | step 2630 | avg_nll=16.60 avg_ppl=10.33 speed=5977.64 words/sec time_elapsed=94.35 sec
# epoch 10 (191/272) | step 2640 | avg_nll=17.01 avg_ppl=10.36 speed=7236.84 words/sec time_elapsed=94.67 sec
# epoch 10 (201/272) | step 2650 | avg_nll=17.16 avg_ppl=10.71 speed=7640.22 words/sec time_elapsed=94.97 sec
# epoch 10 (211/272) | step 2660 | avg_nll=16.61 avg_ppl=10.12 speed=6122.70 words/sec time_elapsed=95.35 sec
# epoch 10 (221/272) | step 2670 | avg_nll=19.10 avg_ppl=13.09 speed=7841.07 words/sec time_elapsed=95.65 sec
# epoch 10 (231/272) | step 2680 | avg_nll=17.95 avg_ppl=11.75 speed=7121.28 words/sec time_elapsed=95.98 sec
# epoch 10 (241/272) | step 2690 | avg_nll=16.74 avg_ppl=10.50 speed=7150.16 words/sec time_elapsed=96.30 sec
# epoch 10 (251/272) | step 2700 | avg_nll=16.57 avg_ppl=10.06 speed=7332.14 words/sec time_elapsed=96.61 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=12.019969940185547
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=16.71 avg_ppl=10.02 speed=3246.66 words/sec time_elapsed=97.33 sec
# epoch 10 (271/272) | step 2720 | avg_nll=17.13 avg_ppl=11.33 speed=6742.67 words/sec time_elapsed=97.66 sec
# epoch 11 (9/272) | step 2730 | avg_nll=16.32 avg_ppl=9.15 speed=6274.45 words/sec time_elapsed=98.04 sec
# epoch 11 (19/272) | step 2740 | avg_nll=16.21 avg_ppl=9.46 speed=6780.85 words/sec time_elapsed=98.38 sec
# epoch 11 (29/272) | step 2750 | avg_nll=15.49 avg_ppl=9.00 speed=5989.05 words/sec time_elapsed=98.76 sec
# epoch 11 (39/272) | step 2760 | avg_nll=16.80 avg_ppl=10.34 speed=7519.60 words/sec time_elapsed=99.06 sec
# epoch 11 (49/272) | step 2770 | avg_nll=17.06 avg_ppl=10.54 speed=6981.90 words/sec time_elapsed=99.39 sec
# epoch 11 (59/272) | step 2780 | avg_nll=16.59 avg_ppl=9.69 speed=7042.26 words/sec time_elapsed=99.73 sec
# epoch 11 (69/272) | step 2790 | avg_nll=16.38 avg_ppl=9.67 speed=6367.75 words/sec time_elapsed=100.09 sec
# epoch 11 (79/272) | step 2800 | avg_nll=18.14 avg_ppl=11.66 speed=6909.99 words/sec time_elapsed=100.43 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=11.73664379119873
# epoch 11 step 2800: save currently the best model to 'model.pt'
# epoch 11 (89/272) | step 2810 | avg_nll=16.89 avg_ppl=10.12 speed=3677.79 words/sec time_elapsed=101.06 sec
# epoch 11 (99/272) | step 2820 | avg_nll=18.12 avg_ppl=11.50 speed=7452.28 words/sec time_elapsed=101.38 sec
# epoch 11 (109/272) | step 2830 | avg_nll=17.18 avg_ppl=10.80 speed=6675.22 words/sec time_elapsed=101.73 sec
# epoch 11 (119/272) | step 2840 | avg_nll=16.98 avg_ppl=10.27 speed=7290.41 words/sec time_elapsed=102.05 sec
# epoch 11 (129/272) | step 2850 | avg_nll=16.83 avg_ppl=10.26 speed=7762.62 words/sec time_elapsed=102.35 sec
# epoch 11 (139/272) | step 2860 | avg_nll=15.39 avg_ppl=8.64 speed=6355.59 words/sec time_elapsed=102.71 sec
# epoch 11 (149/272) | step 2870 | avg_nll=16.70 avg_ppl=9.92 speed=6627.50 words/sec time_elapsed=103.06 sec
# epoch 11 (159/272) | step 2880 | avg_nll=15.66 avg_ppl=9.28 speed=7230.57 words/sec time_elapsed=103.37 sec
# epoch 11 (169/272) | step 2890 | avg_nll=16.84 avg_ppl=10.47 speed=7379.88 words/sec time_elapsed=103.68 sec
# epoch 11 (179/272) | step 2900 | avg_nll=16.45 avg_ppl=9.61 speed=7893.61 words/sec time_elapsed=103.98 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=11.730508804321289
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=16.13 avg_ppl=9.48 speed=4152.02 words/sec time_elapsed=104.53 sec
# epoch 11 (199/272) | step 2920 | avg_nll=16.51 avg_ppl=9.98 speed=7656.07 words/sec time_elapsed=104.83 sec
# epoch 11 (209/272) | step 2930 | avg_nll=17.05 avg_ppl=10.31 speed=7554.10 words/sec time_elapsed=105.14 sec
# epoch 11 (219/272) | step 2940 | avg_nll=17.03 avg_ppl=10.69 speed=7000.52 words/sec time_elapsed=105.47 sec
# epoch 11 (229/272) | step 2950 | avg_nll=16.45 avg_ppl=9.59 speed=7537.80 words/sec time_elapsed=105.78 sec
# epoch 11 (239/272) | step 2960 | avg_nll=16.62 avg_ppl=9.96 speed=6445.73 words/sec time_elapsed=106.14 sec
# epoch 11 (249/272) | step 2970 | avg_nll=16.98 avg_ppl=10.21 speed=6674.42 words/sec time_elapsed=106.49 sec
# epoch 11 (259/272) | step 2980 | avg_nll=17.00 avg_ppl=10.27 speed=6913.09 words/sec time_elapsed=106.83 sec
# epoch 11 (269/272) | step 2990 | avg_nll=16.29 avg_ppl=9.43 speed=6503.62 words/sec time_elapsed=107.19 sec
# epoch 12 (7/272) | step 3000 | avg_nll=16.91 avg_ppl=10.18 speed=7305.13 words/sec time_elapsed=107.51 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=11.517314910888672
# epoch 12 step 3000: save currently the best model to 'model.pt'
# epoch 12 (17/272) | step 3010 | avg_nll=17.10 avg_ppl=10.01 speed=3500.25 words/sec time_elapsed=108.19 sec
# epoch 12 (27/272) | step 3020 | avg_nll=16.33 avg_ppl=9.24 speed=6010.23 words/sec time_elapsed=108.58 sec
# epoch 12 (37/272) | step 3030 | avg_nll=15.67 avg_ppl=8.78 speed=7170.82 words/sec time_elapsed=108.90 sec
# epoch 12 (47/272) | step 3040 | avg_nll=15.69 avg_ppl=8.69 speed=6730.46 words/sec time_elapsed=109.24 sec
# epoch 12 (57/272) | step 3050 | avg_nll=16.28 avg_ppl=9.52 speed=6285.56 words/sec time_elapsed=109.61 sec
# epoch 12 (67/272) | step 3060 | avg_nll=15.72 avg_ppl=9.21 speed=6026.74 words/sec time_elapsed=109.99 sec
# epoch 12 (77/272) | step 3070 | avg_nll=17.35 avg_ppl=10.45 speed=6854.47 words/sec time_elapsed=110.33 sec
# epoch 12 (87/272) | step 3080 | avg_nll=15.56 avg_ppl=9.00 speed=7018.56 words/sec time_elapsed=110.66 sec
# epoch 12 (97/272) | step 3090 | avg_nll=16.14 avg_ppl=9.30 speed=7045.15 words/sec time_elapsed=110.98 sec
# epoch 12 (107/272) | step 3100 | avg_nll=15.61 avg_ppl=8.85 speed=7018.51 words/sec time_elapsed=111.31 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=11.185408592224121
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=16.77 avg_ppl=10.16 speed=3255.91 words/sec time_elapsed=112.02 sec
# epoch 12 (127/272) | step 3120 | avg_nll=16.04 avg_ppl=8.75 speed=6000.19 words/sec time_elapsed=112.42 sec
# epoch 12 (137/272) | step 3130 | avg_nll=15.86 avg_ppl=9.28 speed=6864.52 words/sec time_elapsed=112.75 sec
# epoch 12 (147/272) | step 3140 | avg_nll=16.43 avg_ppl=9.51 speed=6827.56 words/sec time_elapsed=113.09 sec
# epoch 12 (157/272) | step 3150 | avg_nll=16.23 avg_ppl=9.64 speed=6857.48 words/sec time_elapsed=113.43 sec
# epoch 12 (167/272) | step 3160 | avg_nll=15.98 avg_ppl=8.98 speed=6128.95 words/sec time_elapsed=113.81 sec
# epoch 12 (177/272) | step 3170 | avg_nll=15.66 avg_ppl=8.77 speed=6897.50 words/sec time_elapsed=114.14 sec
# epoch 12 (187/272) | step 3180 | avg_nll=15.16 avg_ppl=8.40 speed=7702.75 words/sec time_elapsed=114.44 sec
# epoch 12 (197/272) | step 3190 | avg_nll=15.69 avg_ppl=8.81 speed=7167.73 words/sec time_elapsed=114.76 sec
# epoch 12 (207/272) | step 3200 | avg_nll=16.12 avg_ppl=9.29 speed=7300.19 words/sec time_elapsed=115.08 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=11.151017189025879
# epoch 12 step 3200: save currently the best model to 'model.pt'
# epoch 12 (217/272) | step 3210 | avg_nll=16.30 avg_ppl=9.40 speed=3502.14 words/sec time_elapsed=115.74 sec
# epoch 12 (227/272) | step 3220 | avg_nll=15.85 avg_ppl=9.19 speed=6587.88 words/sec time_elapsed=116.09 sec
# epoch 12 (237/272) | step 3230 | avg_nll=15.95 avg_ppl=9.12 speed=6717.49 words/sec time_elapsed=116.43 sec
# epoch 12 (247/272) | step 3240 | avg_nll=15.82 avg_ppl=8.86 speed=6770.00 words/sec time_elapsed=116.78 sec
# epoch 12 (257/272) | step 3250 | avg_nll=15.67 avg_ppl=8.80 speed=6883.52 words/sec time_elapsed=117.11 sec
# epoch 12 (267/272) | step 3260 | avg_nll=16.32 avg_ppl=9.51 speed=7074.41 words/sec time_elapsed=117.44 sec
# epoch 13 (5/272) | step 3270 | avg_nll=15.74 avg_ppl=8.61 speed=6204.22 words/sec time_elapsed=117.82 sec
# epoch 13 (15/272) | step 3280 | avg_nll=14.98 avg_ppl=7.91 speed=5725.92 words/sec time_elapsed=118.22 sec
# epoch 13 (25/272) | step 3290 | avg_nll=15.49 avg_ppl=8.37 speed=6009.48 words/sec time_elapsed=118.61 sec
# epoch 13 (35/272) | step 3300 | avg_nll=14.82 avg_ppl=7.83 speed=6082.92 words/sec time_elapsed=118.99 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=10.980772018432617
# epoch 13 step 3300: save currently the best model to 'model.pt'
# epoch 13 (45/272) | step 3310 | avg_nll=15.59 avg_ppl=8.79 speed=3196.39 words/sec time_elapsed=119.71 sec
# epoch 13 (55/272) | step 3320 | avg_nll=14.98 avg_ppl=8.15 speed=6291.80 words/sec time_elapsed=120.07 sec
# epoch 13 (65/272) | step 3330 | avg_nll=15.64 avg_ppl=8.47 speed=5620.54 words/sec time_elapsed=120.49 sec
# epoch 13 (75/272) | step 3340 | avg_nll=15.44 avg_ppl=8.66 speed=6160.19 words/sec time_elapsed=120.86 sec
# epoch 13 (85/272) | step 3350 | avg_nll=15.78 avg_ppl=9.20 speed=6733.66 words/sec time_elapsed=121.20 sec
# epoch 13 (95/272) | step 3360 | avg_nll=14.93 avg_ppl=7.97 speed=7036.78 words/sec time_elapsed=121.52 sec
# epoch 13 (105/272) | step 3370 | avg_nll=16.52 avg_ppl=9.79 speed=5304.28 words/sec time_elapsed=121.96 sec
# epoch 13 (115/272) | step 3380 | avg_nll=15.80 avg_ppl=8.91 speed=6820.08 words/sec time_elapsed=122.30 sec
# epoch 13 (125/272) | step 3390 | avg_nll=16.10 avg_ppl=8.99 speed=6141.30 words/sec time_elapsed=122.68 sec
# epoch 13 (135/272) | step 3400 | avg_nll=15.42 avg_ppl=8.45 speed=5472.86 words/sec time_elapsed=123.11 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=10.87116527557373
# epoch 13 step 3400: save currently the best model to 'model.pt'
# epoch 13 (145/272) | step 3410 | avg_nll=15.06 avg_ppl=8.12 speed=3242.56 words/sec time_elapsed=123.81 sec
# epoch 13 (155/272) | step 3420 | avg_nll=16.17 avg_ppl=8.95 speed=5188.31 words/sec time_elapsed=124.27 sec
# epoch 13 (165/272) | step 3430 | avg_nll=16.05 avg_ppl=8.66 speed=3647.55 words/sec time_elapsed=124.92 sec
# epoch 13 (175/272) | step 3440 | avg_nll=15.89 avg_ppl=8.98 speed=4286.10 words/sec time_elapsed=125.46 sec
# epoch 13 (185/272) | step 3450 | avg_nll=16.23 avg_ppl=9.23 speed=3862.57 words/sec time_elapsed=126.07 sec
# epoch 13 (195/272) | step 3460 | avg_nll=15.62 avg_ppl=8.51 speed=4462.89 words/sec time_elapsed=126.59 sec
# epoch 13 (205/272) | step 3470 | avg_nll=15.11 avg_ppl=8.12 speed=4205.15 words/sec time_elapsed=127.14 sec
# epoch 13 (215/272) | step 3480 | avg_nll=15.72 avg_ppl=8.55 speed=4805.63 words/sec time_elapsed=127.63 sec
# epoch 13 (225/272) | step 3490 | avg_nll=16.81 avg_ppl=9.67 speed=6567.14 words/sec time_elapsed=127.99 sec
# epoch 13 (235/272) | step 3500 | avg_nll=15.30 avg_ppl=8.58 speed=6269.90 words/sec time_elapsed=128.35 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=10.724419593811035
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=15.98 avg_ppl=8.83 speed=3165.23 words/sec time_elapsed=129.10 sec
# epoch 13 (255/272) | step 3520 | avg_nll=14.35 avg_ppl=7.59 speed=5335.80 words/sec time_elapsed=129.52 sec
# epoch 13 (265/272) | step 3530 | avg_nll=16.02 avg_ppl=9.15 speed=5485.04 words/sec time_elapsed=129.94 sec
# epoch 14 (3/272) | step 3540 | avg_nll=15.09 avg_ppl=8.17 speed=5690.78 words/sec time_elapsed=130.35 sec
# epoch 14 (13/272) | step 3550 | avg_nll=14.56 avg_ppl=7.59 speed=5849.59 words/sec time_elapsed=130.74 sec
# epoch 14 (23/272) | step 3560 | avg_nll=14.79 avg_ppl=7.76 speed=6226.72 words/sec time_elapsed=131.11 sec
# epoch 14 (33/272) | step 3570 | avg_nll=15.10 avg_ppl=8.00 speed=6229.59 words/sec time_elapsed=131.49 sec
# epoch 14 (43/272) | step 3580 | avg_nll=15.35 avg_ppl=8.32 speed=4619.38 words/sec time_elapsed=131.99 sec
# epoch 14 (53/272) | step 3590 | avg_nll=14.54 avg_ppl=7.62 speed=5291.73 words/sec time_elapsed=132.42 sec
# epoch 14 (63/272) | step 3600 | avg_nll=13.74 avg_ppl=6.70 speed=5982.79 words/sec time_elapsed=132.81 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=10.720991134643555
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=16.01 avg_ppl=8.80 speed=3041.97 words/sec time_elapsed=133.59 sec
# epoch 14 (83/272) | step 3620 | avg_nll=15.20 avg_ppl=8.17 speed=5312.29 words/sec time_elapsed=134.02 sec
# epoch 14 (93/272) | step 3630 | avg_nll=15.64 avg_ppl=8.49 speed=4957.55 words/sec time_elapsed=134.49 sec
# epoch 14 (103/272) | step 3640 | avg_nll=14.62 avg_ppl=7.76 speed=4639.60 words/sec time_elapsed=134.99 sec
# epoch 14 (113/272) | step 3650 | avg_nll=13.51 avg_ppl=6.94 speed=5428.22 words/sec time_elapsed=135.40 sec
# epoch 14 (123/272) | step 3660 | avg_nll=15.46 avg_ppl=8.45 speed=6268.55 words/sec time_elapsed=135.77 sec
# epoch 14 (133/272) | step 3670 | avg_nll=16.21 avg_ppl=9.01 speed=6868.67 words/sec time_elapsed=136.11 sec
# epoch 14 (143/272) | step 3680 | avg_nll=15.04 avg_ppl=7.97 speed=5326.41 words/sec time_elapsed=136.55 sec
# epoch 14 (153/272) | step 3690 | avg_nll=15.87 avg_ppl=8.57 speed=5644.41 words/sec time_elapsed=136.97 sec
# epoch 14 (163/272) | step 3700 | avg_nll=14.61 avg_ppl=7.54 speed=4426.45 words/sec time_elapsed=137.49 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=10.463160514831543
# epoch 14 step 3700: save currently the best model to 'model.pt'
# epoch 14 (173/272) | step 3710 | avg_nll=15.02 avg_ppl=8.31 speed=3040.66 words/sec time_elapsed=138.24 sec
# epoch 14 (183/272) | step 3720 | avg_nll=14.67 avg_ppl=7.72 speed=6476.61 words/sec time_elapsed=138.59 sec
# epoch 14 (193/272) | step 3730 | avg_nll=16.00 avg_ppl=9.04 speed=6097.42 words/sec time_elapsed=138.97 sec
# epoch 14 (203/272) | step 3740 | avg_nll=16.03 avg_ppl=8.78 speed=6418.89 words/sec time_elapsed=139.34 sec
# epoch 14 (213/272) | step 3750 | avg_nll=15.11 avg_ppl=8.09 speed=6481.95 words/sec time_elapsed=139.70 sec
# epoch 14 (223/272) | step 3760 | avg_nll=13.72 avg_ppl=6.72 speed=6154.86 words/sec time_elapsed=140.07 sec
# epoch 14 (233/272) | step 3770 | avg_nll=14.94 avg_ppl=7.82 speed=5058.23 words/sec time_elapsed=140.53 sec
# epoch 14 (243/272) | step 3780 | avg_nll=14.39 avg_ppl=7.61 speed=5032.34 words/sec time_elapsed=140.98 sec
# epoch 14 (253/272) | step 3790 | avg_nll=15.18 avg_ppl=8.02 speed=5031.71 words/sec time_elapsed=141.45 sec
# epoch 14 (263/272) | step 3800 | avg_nll=14.94 avg_ppl=7.88 speed=4082.08 words/sec time_elapsed=142.02 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=10.134262084960938
# epoch 14 step 3800: save currently the best model to 'model.pt'
# epoch 15 (1/272) | step 3810 | avg_nll=16.17 avg_ppl=8.86 speed=2614.61 words/sec time_elapsed=142.92 sec
# epoch 15 (11/272) | step 3820 | avg_nll=14.78 avg_ppl=7.67 speed=4969.91 words/sec time_elapsed=143.39 sec
# epoch 15 (21/272) | step 3830 | avg_nll=14.69 avg_ppl=7.67 speed=7099.38 words/sec time_elapsed=143.72 sec
# epoch 15 (31/272) | step 3840 | avg_nll=14.18 avg_ppl=7.00 speed=6801.75 words/sec time_elapsed=144.06 sec
# epoch 15 (41/272) | step 3850 | avg_nll=13.21 avg_ppl=6.43 speed=6545.36 words/sec time_elapsed=144.41 sec
# epoch 15 (51/272) | step 3860 | avg_nll=14.28 avg_ppl=7.25 speed=5654.43 words/sec time_elapsed=144.82 sec
# epoch 15 (61/272) | step 3870 | avg_nll=14.85 avg_ppl=7.76 speed=6454.86 words/sec time_elapsed=145.17 sec
# epoch 15 (71/272) | step 3880 | avg_nll=15.28 avg_ppl=7.84 speed=6861.37 words/sec time_elapsed=145.52 sec
# epoch 15 (81/272) | step 3890 | avg_nll=14.33 avg_ppl=7.23 speed=6507.78 words/sec time_elapsed=145.88 sec
# epoch 15 (91/272) | step 3900 | avg_nll=15.93 avg_ppl=8.74 speed=7734.52 words/sec time_elapsed=146.18 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=9.857095718383789
# epoch 15 step 3900: save currently the best model to 'model.pt'
# epoch 15 (101/272) | step 3910 | avg_nll=15.19 avg_ppl=8.08 speed=3467.95 words/sec time_elapsed=146.85 sec
# epoch 15 (111/272) | step 3920 | avg_nll=14.19 avg_ppl=7.33 speed=5769.63 words/sec time_elapsed=147.25 sec
# epoch 15 (121/272) | step 3930 | avg_nll=15.08 avg_ppl=7.94 speed=6682.39 words/sec time_elapsed=147.60 sec
# epoch 15 (131/272) | step 3940 | avg_nll=14.24 avg_ppl=7.26 speed=7341.28 words/sec time_elapsed=147.91 sec
# epoch 15 (141/272) | step 3950 | avg_nll=14.27 avg_ppl=7.17 speed=7880.92 words/sec time_elapsed=148.20 sec
# epoch 15 (151/272) | step 3960 | avg_nll=14.65 avg_ppl=7.64 speed=7532.69 words/sec time_elapsed=148.51 sec
# epoch 15 (161/272) | step 3970 | avg_nll=14.08 avg_ppl=7.06 speed=7367.36 words/sec time_elapsed=148.82 sec
# epoch 15 (171/272) | step 3980 | avg_nll=14.88 avg_ppl=7.81 speed=7559.01 words/sec time_elapsed=149.13 sec
# epoch 15 (181/272) | step 3990 | avg_nll=14.72 avg_ppl=7.54 speed=7799.32 words/sec time_elapsed=149.43 sec
# epoch 15 (191/272) | step 4000 | avg_nll=13.94 avg_ppl=6.88 speed=7633.66 words/sec time_elapsed=149.73 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=9.99200439453125
# epoch 15 (201/272) | step 4010 | avg_nll=13.40 avg_ppl=6.71 speed=4063.27 words/sec time_elapsed=150.29 sec
# epoch 15 (211/272) | step 4020 | avg_nll=15.03 avg_ppl=7.83 speed=7232.24 words/sec time_elapsed=150.61 sec
# epoch 15 (221/272) | step 4030 | avg_nll=14.07 avg_ppl=7.10 speed=7530.66 words/sec time_elapsed=150.92 sec
# epoch 15 (231/272) | step 4040 | avg_nll=13.74 avg_ppl=6.70 speed=6984.79 words/sec time_elapsed=151.25 sec
# epoch 15 (241/272) | step 4050 | avg_nll=15.38 avg_ppl=8.12 speed=6385.87 words/sec time_elapsed=151.62 sec
# epoch 15 (251/272) | step 4060 | avg_nll=14.47 avg_ppl=7.30 speed=7090.67 words/sec time_elapsed=151.95 sec
# epoch 15 (261/272) | step 4070 | avg_nll=15.56 avg_ppl=8.35 speed=7497.59 words/sec time_elapsed=152.26 sec
# epoch 15 (271/272) | step 4080 | avg_nll=14.85 avg_ppl=7.98 speed=5693.16 words/sec time_elapsed=152.66 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score: 
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# Use device: cuda:0
# 100%|██████████| 486/486 [01:19<00:00,  6.13it/s]
# Corpus BLEU: 43.40483426233298

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(20, 40):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 20 =====
# Input:  je suis fier de vous tous .
# Gold:  i m proud of you all .
# Pred:  i m proud of you .
# ===== Sample 21 =====
# Input:  vous etes un merveilleux ami .
# Gold:  you re a wonderful friend .
# Pred:  you re a good his .
# ===== Sample 22 =====
# Input:  il a l habitude des ordinateurs .
# Gold:  he is familiar with computers .
# Pred:  he s the replaceable to .
# ===== Sample 23 =====
# Input:  vous etes plus grands que moi .
# Gold:  you re taller than i am .
# Pred:  you re taller than me .
# ===== Sample 24 =====
# Input:  vous avez peur pas vrai ?
# Gold:  you re afraid aren t you ?
# Pred:  you re t aren t you ?
# ===== Sample 25 =====
# Input:  je ne fais pas partie de leur bande .
# Gold:  i m not one of them .
# Pred:  i m not one to .
# ===== Sample 26 =====
# Input:  vous etes tres comprehensives .
# Gold:  you re very understanding .
# Pred:  you re very good .
# ===== Sample 27 =====
# Input:  vous vous approchez .
# Gold:  you re getting closer .
# Pred:  you re tired .
# ===== Sample 28 =====
# Input:  vous dites toujours ca .
# Gold:  you re always saying that .
# Pred:  you re always not it .
# ===== Sample 29 =====
# Input:  je conte une histoire .
# Gold:  i am telling a story .
# Pred:  i m glad to help .
# ===== Sample 30 =====
# Input:  il est photographe professionnel .
# Gold:  he s a professional photographer .
# Pred:  he s a a a .
# ===== Sample 31 =====
# Input:  vous etes incroyables .
# Gold:  you re incredible .
# Pred:  you re amazing .
# ===== Sample 32 =====
# Input:  je suis desole .
# Gold:  i m sorry .
# Pred:  i m sorry .
# ===== Sample 33 =====
# Input:  elle lui sourit avec gene .
# Gold:  she smiled at him uneasily .
# Pred:  she is going to him .
# ===== Sample 34 =====
# Input:  nous sommes freres .
# Gold:  we re brothers .
# Pred:  we re going .
# ===== Sample 35 =====
# Input:  vous n etes pas fatiguees si ?
# Gold:  you re not tired are you ?
# Pred:  you re not tired are you ?
# ===== Sample 36 =====
# Input:  nous sommes debout .
# Gold:  we re standing .
# Pred:  we re greatest .
# ===== Sample 37 =====
# Input:  je casse mes nouvelles chaussures .
# Gold:  i m breaking in my new shoes .
# Pred:  i m trying to the your .
# ===== Sample 38 =====
# Input:  je crains de vous avoir offense .
# Gold:  i m afraid i ve offended you .
# Pred:  i m afraid i you .
# ===== Sample 39 =====
# Input:  vous conduisez comme un tare !
# Gold:  you re driving like a maniac !
# Pred:  you re a a liar .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?

# %% [markdown]
# **(e) Comparison with Pretrained LLMs (10 points)**
#
# 1.	Objective: cCompare the performance of your trained Transformer-based NMT model with that of a pretrained large language model (LLM) available through Hugging Face.
#
# 2.	Procedure:
# - Select a Pretrained Model:
#     Choose a pretrained LLM from Hugging Face (e.g., MarianMT, T5, or any translationcapable model). Briefly describe your choice
#
# - Experimental Setup:
#     Run the selected LLM on the test set. Ensure that the experimental setup (e.g., input formatting, temperature settings, etc.) is documented.
#
# -  Quantitative Evaluation:
#     Compute the BLEU score for the pretrained model’s translations.
#
# - Qualitative Analysis:
#     Manually inspect several translation examples from both your model and the pretrained LLM. Compare aspects such as fluency, grammatical correctness, and adequacy of translation.
#
# - Discussion:
#     Discuss the differences in performance, computational resource requirements, and any potential trade-offs between your custom-built model and the pretrained Hugging Face model.
#
# **Deliverable**
#
# - Include your code, evaluation results, and a brief discussion in the notebook or a separate pdf file.

# %% [markdown]
# ## Answer for B(II)

# %%
from torch.utils.data import DataLoader

# Create a DataLoader for the training set
# and apply the collate function to pad the sequences in each batch
# we need to do this to count the average number of padding tokens
train_loader = DataLoader(
    dataset=tokenized_datasets["train"],
    batch_size=32,
    shuffle=True,
    collate_fn=collate_fn,
)

n_source_tokens = []
n_target_token = []
n_source_padding_token = []
n_target_padding_token = []

# We need to iterate over every batch because not all batches have the same size
for batch in train_loader:
    # we want the encoder_input_ids and decoder_input_ids tensors
    encoder_input_ids = batch["encoder_input_ids"]
    decoder_input_ids = batch["decoder_input_ids"]

    # we can now count how many tokens are in the encoder_input_ids and decoder_input_ids tensors
    n_source_tokens.append(encoder_input_ids.numel()) # .numel() returns the number of elements in the tensor as an int
    n_target_token.append(decoder_input_ids.numel())

    # Next we count the amount of padding tokens in the encoder_input_ids and decoder_input_ids tensors
    n_source_padding_token.append((encoder_input_ids == source_tokenizer.pad_token_id).sum().item()) # .item() to convert to a python int
    n_target_padding_token.append((decoder_input_ids == target_tokenizer.pad_token_id).sum().item())

# we can now compute the average number of tokens in the encoder_input_ids and decoder_input_ids tensors
source_token_count = sum(n_source_tokens) / len(n_source_tokens)
target_token_count = sum(n_target_token) / len(n_target_token)
print(f"Average number of tokens in encoder_input_ids: {source_token_count:.0f}")
print(f"Average number of tokens in decoder_input_ids: {target_token_count:.0f}")

# we can now compute the average amount of padding tokens in the encoder_input_ids and decoder_input_ids tensors
prop_source_padding_token = sum(n_source_padding_token) / sum(n_source_tokens)
prop_target_padding_token = sum(n_target_padding_token) / sum(n_target_token)
print(f"Average proportion of padding tokens in encoder_input_ids: {prop_source_padding_token:.2%}")
print(f"Average proportion of padding tokens in decoder_input_ids: {prop_target_padding_token:.2%}")
# Out:
# Average number of tokens in encoder_input_ids: 436
# Average number of tokens in decoder_input_ids: 374
# Average proportion of padding tokens in encoder_input_ids: 34.07%
# Average proportion of padding tokens in decoder_input_ids: 29.59%

# %%
#https://huggingface.co/docs/transformers/model_doc/marian

from transformers import MarianMTModel, MarianTokenizer
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

# MarianMTModel from the Transformers library
src_lang = "fr" # Source language (French)
tgt_lang = "en" # Target language (English)
marian_model_name = f"Helsinki-NLP/opus-mt-{src_lang}-{tgt_lang}"

# Load the model and tokenizer
marian_model = MarianMTModel.from_pretrained(marian_model_name)
tokenizer = MarianTokenizer.from_pretrained(marian_model_name)
print(f"Loaded model: {marian_model_name}")
print(f"Model architecture: {marian_model}")

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Using device: %s' % device)
marian_model.to(device)

# Load datasets
src_texts = raw_text_datasets['test']['text_fr']
tgt_texts = raw_text_datasets['test']['text_en']

input_sentences = []
reference_sentences = []
candidate_sentences = []

with torch.no_grad():
    for example in tqdm(raw_text_datasets["test"]):
        src = example["text_fr"]
        tgt = example["text_en"]

        # Tokenize source text only
        inputs = tokenizer(src, return_tensors="pt", padding=True).to(device)
        
        # Generate tokenised translation
        generation = marian_model.generate(**inputs, max_length=50, num_beams=5, temperature=0.07)
        
        # Decode generated text
        candidate_text = tokenizer.decode(generation[0], skip_special_tokens=True)
        
        # Append results (using original texts for input and reference)
        input_sentences.append(src)
        reference_sentences.append(tgt)
        candidate_sentences.append(candidate_text)

bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])
print('\nCorpus BLEU: {:.2f}'.format(bleu_score * 100))

# Print examples
for k in range(20, 40):
    print(f"===== Sample {k} =====")
    print(f"Input: {input_sentences[k]}")
    print(f"Gold: {reference_sentences[k]}")
    print(f"Pred: {candidate_sentences[k]}\n")
# Out:
# c:\Users\m3vde\OneDrive\Desktop\LifeOS\02 Areas\University\Year 2\2a\Natural-Language-Processing\.venv\lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loaded model: Helsinki-NLP/opus-mt-fr-en
# Model architecture: MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(59514, 512, padding_idx=59513)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(59514, 512, padding_idx=59513)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLUActivation()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): MarianDecoder(
#       (embed_tokens): Embedding(59514, 512, padding_idx=59513)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLUActivation()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=512, out_features=59514, bias=False)
# )
# Using device: cuda:0
# 100%|██████████| 486/486 [01:53<00:00,  4.30it/s]
# Corpus BLEU: 59.46
# ===== Sample 20 =====
# Input: je suis fier de vous tous .
# Gold: i m proud of you all .
# Pred: I'm proud of all of you.
#
# ===== Sample 21 =====
# Input: vous etes un merveilleux ami .
# Gold: you re a wonderful friend .
# Pred: You're a wonderful friend.
#
# ===== Sample 22 =====
# Input: il a l habitude des ordinateurs .
# Gold: he is familiar with computers .
# Pred: He's used to computers.
#
# ===== Sample 23 =====
# Input: vous etes plus grands que moi .
# Gold: you re taller than i am .
# Pred: You're bigger than me.
#
# ===== Sample 24 =====
# Input: vous avez peur pas vrai ?
# Gold: you re afraid aren t you ?
# Pred: You're afraid, aren't you?
#
# ===== Sample 25 =====
# Input: je ne fais pas partie de leur bande .
# Gold: i m not one of them .
# Pred: I'm not part of their gang.
#
# ===== Sample 26 =====
# Input: vous etes tres comprehensives .
# Gold: you re very understanding .
# Pred: You're very understanding.
#
# ===== Sample 27 =====
# Input: vous vous approchez .
# Gold: you re getting closer .
# Pred: You're approaching.
#
# ===== Sample 28 =====
# Input: vous dites toujours ca .
# Gold: you re always saying that .
# Pred: You always say that.
#
# ===== Sample 29 =====
# Input: je conte une histoire .
# Gold: i am telling a story .
# Pred: I'm telling a story.
#
# ===== Sample 30 =====
# Input: il est photographe professionnel .
# Gold: he s a professional photographer .
# Pred: He's a professional photographer.
#
# ===== Sample 31 =====
# Input: vous etes incroyables .
# Gold: you re incredible .
# Pred: You're amazing.
#
# ===== Sample 32 =====
# Input: je suis desole .
# Gold: i m sorry .
# Pred: I'm sorry.
#
# ===== Sample 33 =====
# Input: elle lui sourit avec gene .
# Gold: she smiled at him uneasily .
# Pred: She smiles at him with gene.
#
# ===== Sample 34 =====
# Input: nous sommes freres .
# Gold: we re brothers .
# Pred: We're brothers.
#
# ===== Sample 35 =====
# Input: vous n etes pas fatiguees si ?
# Gold: you re not tired are you ?
# Pred: You're not tired, are you?
#
# ===== Sample 36 =====
# Input: nous sommes debout .
# Gold: we re standing .
# Pred: We're up.
#
# ===== Sample 37 =====
# Input: je casse mes nouvelles chaussures .
# Gold: i m breaking in my new shoes .
# Pred: I'm breaking my new shoes.
#
# ===== Sample 38 =====
# Input: je crains de vous avoir offense .
# Gold: i m afraid i ve offended you .
# Pred: I'm afraid I've offended you.
#
# ===== Sample 39 =====
# Input: vous conduisez comme un tare !
# Gold: you re driving like a maniac !
# Pred: You're driving like a tare!
